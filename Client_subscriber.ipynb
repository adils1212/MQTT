# %% [markdown]
# ## ENPM 809F Final Project
# ## MQTT Protocol Simulation for Home Automation System
# ## Muhammad Adil Sohail & Waleed Waris
# ## 12/14/2020
#
# * This project script will create an IoT simulation which will use MQTT protocol to simulate an IoT network in a home automation system. The simulation will leverage a dataset that provides actual data from sensors in a home automation system such as temperature, humidity, light on/off, etc. Data from the dataset will be read, published to a broker, and recieved by a smartphone application that is subscribed to the proper topic. In addition, commands for certain controllers can be sent from the smartphone application.
#
# * This is one of the two modules for the project. The other being Client_publisher. This module will read the published messages from Client_publisher. A smartphone application will be subscribed to the respective topic on the server, recieve the sensor data, and print it. Also, controllers subscribed to the respective topic will receive commands sent from the mobile_devices.
#
# * A GUI will be leveraged to display the sensor data / actuator commands

# %% [markdown]
# ## 1.0 Define MQTT Protocol Functions

# %%
# Import Neccesary Libraries 
import paho.mqtt.client as mqtt
import time
import pandas as pd
import os 
import copy
from tkinter import *
import time
import datetime

# %%
# Defines callback function to show when mobile_device has connected. Also, mobile_device subscribes to proper topic.

def on_connect_mobile_device(client, userdata, flags, rc):
    print("Connected with result code "+str(rc))
    client.subscribe("house/livingroom/time")
    client.subscribe("house/livingroom/CO")
    client.subscribe("house/livingroom/humidity")
    client.subscribe("house/livingroom/lightdetected")
    client.subscribe("house/livingroom/lpg")
    client.subscribe("house/livingroom/motiondetected")
    client.subscribe("house/livingroom/smoke")
    client.subscribe("house/livingroom/temp")

# %%
# The following lines of code will store the published/subscribed messages in a database based on a topic
# data_store.pop(0)
def update_df(data_store):
    
    composite_list = [data_store[x:x+8] for x in range(0, len(data_store),8)] #Splits data by 8 entires 
    df_Smarthome = pd.DataFrame.from_records(composite_list) #creates dataframe to store all data
    df_Smarthome.columns = ['time','CO','Humidity','Light','lpg','motion','smoke','temp']
    df_Smarthome.to_csv('smarthome.csv', index = False)

# %%
# Defines callback function to print the subscribed message from the server for the mobile_device
data_store=[]

def on_message_mobile_device(client, userdata, msg):
    
    a=msg.payload.decode("utf-8")
    print(f"{msg.topic} {str(a)}")
    data_store.append(a)
    if msg.topic=="house/livingroom/temp":
        print('\n')
        update_df(data_store)

# %%
# Defines callback function to show when devices have connected. 

def on_connect(client, userdata, flags, rc):
    print("Connected with result code "+str(rc))

# %%
# Defines callback function to print the subscribed message from the server for the devices

def on_message(client, userdata, msg):
    
    a=msg.payload.decode("utf-8")
    print(f"{msg.topic} {str(a)}")
    print("")

# %% [markdown]
# ## 2.0 MQTT Protocol Execution
#
# * The following code will have clients subscribed to specific topics receive messages from the broker (i.e. commands or data) and print them
# * Mobile Device will receive sensor data messages and contoller devices will receive command data messages from mobile devices

# %%
# The portion of the code will focus on the controller commands from the mobile_device

if __name__ == '__main__':
   
    client8=mqtt.Client(client_id="temp_Controller") #Define Clients
    client9=mqtt.Client(client_id="light_Controller")
    client10=mqtt.Client(client_id="fan_Controller")
    
    client8.connect("localhost", 1883) #Connect client to server 
    client9.connect("localhost", 1883) 
    client10.connect("localhost", 1883) 
        
    client8.loop_start()  #Start client loop
    client8.subscribe("house/livingroom/temp/set")   
    client8.on_message = on_message #Print published message
   
    client9.loop_start()
    client9.subscribe("house/livingroom/Light")
    client9.on_message = on_message
        
    client10.loop_start()
    client10.subscribe("house/livingroom/Fan")
    client10.on_message = on_message
# Out:
# house/livingroom/temp/set 100house/livingroom/Light ON
#
# house/livingroom/Fan ON

# %%
#The mobile_device will connect to the broker, recieve the published messages, and print them. 

if __name__ == '__main__':
    
    client_mobile_device = mqtt.Client()
    
    client_mobile_device.connect("localhost", 1883)
        
    client_mobile_device.loop_start()

    client_mobile_device.on_connect = on_connect_mobile_device
    client_mobile_device.on_message = on_message_mobile_device 
    
# wait = input("Press Enter to continue.") #Please press enter only once the Client_publisher.py has been executed
# Out:
# Connected with result code 0

# %% [markdown]
# ## 4.0 Smarthome GUI

# %%
# The portion of the code will create a GUI to display the results 
# i.e. the subcribed sensor data

window=Tk() #Load GUI screen
window.title('Smarthome MQTT Protocol Simulation')
window.geometry("400x310")
df_Smarthome=pd.read_csv("smarthome.csv")
lbl=Label(window, text="Smarthome Application", fg='Blue', font=("Helvetica", 16)) #Create title 
lbl.place(x=80, y=10)

# Create and place sensor ids as labels below

lbl1=Label(window, text= "Date / Time")
lbl1.place(x=20, y=70)
lbl2=Label(window, text= "CO Levels (ppm %)")
lbl2.place(x=20, y=100)
lbl3=Label(window, text= "Humidity Levels (%)" )
lbl3.place(x=20, y=130)
lbl4=Label(window, text= "Light Detected")
lbl4.place(x=20, y=160)
lbl5=Label(window, text= "LPG Levels (ppm %)")
lbl5.place(x=20, y=190)
lbl6=Label(window, text= "Motion Detected")
lbl6.place(x=20, y=220)
lbl7=Label(window, text= "Smoke Levels (ppm %)")
lbl7.place(x=20, y=250)
lbl8=Label(window, text= "Temperature (deg F)")
lbl8.place(x=20, y=280)

lbl9=Label(window, text="Connection Established",bg="green",fg="white")
lbl9.place(x=250, y= 40)

#Create and prints sensor data (i.e.e published/subscribed messages) as labels

#Sets variables to be called in a function
variable_Time=StringVar()
variable_CO=StringVar()
variable_Humidity=StringVar()
variable_Light=StringVar()
variable_LPG=StringVar()
variable_Motion=StringVar()
variable_Smoke=StringVar()
variable_Temp=StringVar()

def update_label(): #Creates function to update through sensor data
    for [ind,row] in df_Smarthome.iterrows(): #iterates through sensor dataframe
        variable_Time.set(str(row[0]))
        variable_CO.set(str(row[1]))
        variable_Humidity.set(str(row[2]))
        variable_Light.set(str(row[3]))
        variable_LPG.set(str(row[4]))
        variable_Motion.set(str(row[5]))
        variable_Smoke.set(str(row[6]))
        variable_Temp.set(str(row[7]))
        window.update()
        window.after(1000) 
        
lbl1data=Label(window, borderwidth=3, width=25, relief='sunken',textvariable=variable_Time)
lbl1data.place(x=150,y=70)
lbl2data=Label(window, borderwidth=3, width=25, relief='sunken',textvariable=variable_CO)
lbl2data.place(x=150,y=100)
lbl3data=Label(window, borderwidth=3, width=25, relief='sunken',textvariable=variable_Humidity)
lbl3data.place(x=150,y=130)
lbl4data=Label(window, borderwidth=3, width=25, relief='sunken',textvariable=variable_Light)
lbl4data.place(x=150,y=160)
lbl5data=Label(window, borderwidth=3, width=25, relief='sunken',textvariable= variable_LPG)
lbl5data.place(x=150,y=190)
lbl6data=Label(window, borderwidth=3, width=25, relief='sunken',textvariable=variable_Motion)
lbl6data.place(x=150,y=220)
lbl7data=Label(window, borderwidth=3, width=25, relief='sunken',textvariable=variable_Smoke)
lbl7data.place(x=150,y=250)
lbl8data=Label(window, borderwidth=3, width=25, relief='sunken',textvariable=variable_Temp)
lbl8data.place(x=150,y=280)

start_button=Button(window,text="Start Simulation",command=update_label)
start_button.place(x=20,y=40)

window.mainloop()
# Out:
# house/livingroom/time 2020-07-12 00:01:34.385969877
# house/livingroom/CO 0.004955939
# house/livingroom/humidity 51.0
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007650822
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.02041127
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:02:11.247800112
# house/livingroom/CO 0.004956119
# house/livingroom/humidity 50.9
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007651024
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020411845
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:02:48.364009857
# house/livingroom/CO 0.004941779
# house/livingroom/humidity 50.9
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007635003
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020366191
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:03:25.213350058
# house/livingroom/CO 0.004984649
# house/livingroom/humidity 51.0
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00768286
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020502582
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:04:02.569639921
# house/livingroom/CO 0.004976012
# house/livingroom/humidity 50.9
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007673227
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020475126
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:04:39.424630165
# house/livingroom/CO 0.004991805
# house/livingroom/humidity 51.0
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007690836
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.02052532
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:05:16.277719975
# house/livingroom/CO 0.005000431
# house/livingroom/humidity 50.9
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007700449
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020552724
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:05:53.351799965
# house/livingroom/CO 0.004991763
# house/livingroom/humidity 51.0
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00769079
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020525187
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:06:30.206259966
# house/livingroom/CO 0.004958991
# house/livingroom/humidity 51.0
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007654231
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020420984
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:07:07.073790073
# house/livingroom/CO 0.004997519
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007697204
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020543474
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:07:43.890909910
# house/livingroom/CO 0.005004798
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007705313
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020566593
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:08:20.765259981
# house/livingroom/CO 0.004988856
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00768755
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020515952
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:08:57.534960032
# house/livingroom/CO 0.004991805
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007690836
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.02052532
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:09:34.396950006
# house/livingroom/CO 0.004987588
# house/livingroom/humidity 50.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007686136
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.02051192
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:10:11.259360075
# house/livingroom/CO 0.004978819
# house/livingroom/humidity 49.5
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007676358
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020484049
# house/livingroom/temp 22.5
#
#
# house/livingroom/time 2020-07-12 00:10:48.118550062
# house/livingroom/CO 0.005023652
# house/livingroom/humidity 49.3
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007726301
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020626438
# house/livingroom/temp 22.4
#
#
# house/livingroom/time 2020-07-12 00:11:24.926509857
# house/livingroom/CO 0.005029451
# house/livingroom/humidity 49.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007732751
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020644832
# house/livingroom/temp 22.3
#
#
# house/livingroom/time 2020-07-12 00:12:02.028599977
# house/livingroom/CO 0.004976012
# house/livingroom/humidity 49.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007673227
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020475126
# house/livingroom/temp 22.3
#
#
# house/livingroom/time 2020-07-12 00:12:38.888339996
# house/livingroom/CO 0.004990367
# house/livingroom/humidity 48.9
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007689234
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020520753
# house/livingroom/temp 22.2
#
#
# house/livingroom/time 2020-07-12 00:13:15.744640112
# house/livingroom/CO 0.004986014
# house/livingroom/humidity 48.9
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007684382
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.02050692
# house/livingroom/temp 22.2
#
#
# house/livingroom/time 2020-07-12 00:13:52.578330040
# house/livingroom/CO 0.004983112
# house/livingroom/humidity 48.8
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007681145
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020497694
# house/livingroom/temp 22.1
#
#
# house/livingroom/time 2020-07-12 00:14:29.452059984
# house/livingroom/CO 0.00499186
# house/livingroom/humidity 48.8
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007690898
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020525496
# house/livingroom/temp 22.1
#
#
# house/livingroom/time 2020-07-12 00:15:06.311300039
# house/livingroom/CO 0.005020725
# house/livingroom/humidity 48.9
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007723043
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020617148
# house/livingroom/temp 22.0
#
#
# house/livingroom/time 2020-07-12 00:15:43.168900013
# house/livingroom/CO 0.004990367
# house/livingroom/humidity 49.5
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007689234
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020520753
# house/livingroom/temp 22.0
#
#
# house/livingroom/time 2020-07-12 00:16:20.029010057
# house/livingroom/CO 0.005020725
# house/livingroom/humidity 50.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007723043
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020617148
# house/livingroom/temp 22.0
#
#
# house/livingroom/time 2020-07-12 00:16:56.866880178
# house/livingroom/CO 0.005038194
# house/livingroom/humidity 50.8
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007742474
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.02067256
# house/livingroom/temp 22.1
#
#
# house/livingroom/time 2020-07-12 00:17:33.726740122
# house/livingroom/CO 0.005044054
# house/livingroom/humidity 50.5
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007748987
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020691137
# house/livingroom/temp 22.1
#
#
# house/livingroom/time 2020-07-12 00:18:10.587480068
# house/livingroom/CO 0.005039661
# house/livingroom/humidity 50.6
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007744104
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020677211
# house/livingroom/temp 22.2
#
#
# house/livingroom/time 2020-07-12 00:18:47.444350004
# house/livingroom/CO 0.005001927
# house/livingroom/humidity 50.4
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007702115
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020557476
# house/livingroom/temp 22.2
#
#
# house/livingroom/time 2020-07-12 00:19:24.297509909
# house/livingroom/CO 0.005020725
# house/livingroom/humidity 51.3
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007723043
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020617148
# house/livingroom/temp 22.2
# house/livingroom/time 2020-07-12 00:20:01.154890060
# house/livingroom/CO 0.005033871
# house/livingroom/humidity 50.5
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007737666
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.02065885
# house/livingroom/temp 22.3
#
#
# house/livingroom/time 2020-07-12 00:20:37.939199924
# house/livingroom/CO 0.005061692
# house/livingroom/humidity 50.8
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007768579
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020747022
# house/livingroom/temp 22.3
#
#
# house/livingroom/time 2020-07-12 00:21:14.727630138
# house/livingroom/CO 0.005073504
# house/livingroom/humidity 50.6
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007781689
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020784424
# house/livingroom/temp 22.3
#
#
# house/livingroom/time 2020-07-12 00:21:51.585080147
# house/livingroom/CO 0.005022228
# house/livingroom/humidity 51.0
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007724716
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020621918
# house/livingroom/temp 22.4
#
#
# house/livingroom/time 2020-07-12 00:22:28.438930035
# house/livingroom/CO 0.005066188
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00777357
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.02076126
# house/livingroom/temp 22.4
#
#
# house/livingroom/time 2020-07-12 00:23:05.556879997
# house/livingroom/CO 0.00504556
# house/livingroom/humidity 50.9
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007750661
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020695911
# house/livingroom/temp 22.4
#
#
# house/livingroom/time 2020-07-12 00:23:42.410749912
# house/livingroom/CO 0.005064653
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007771866
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020756399
# house/livingroom/temp 22.4
#
#
# house/livingroom/time 2020-07-12 00:24:19.160660028
# house/livingroom/CO 0.005051393
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007757141
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020714395
# house/livingroom/temp 22.5
#
#
# house/livingroom/time 2020-07-12 00:24:56.022279978
# house/livingroom/CO 0.005066107
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00777348
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020761005
# house/livingroom/temp 22.5
#
#
# house/livingroom/time 2020-07-12 00:25:32.899260044
# house/livingroom/CO 0.005049959
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007755548
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020709852
# house/livingroom/temp 22.5
#
#
# house/livingroom/time 2020-07-12 00:26:09.767570019
# house/livingroom/CO 0.00506906
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007776758
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020770355
# house/livingroom/temp 22.5
#
#
# house/livingroom/time 2020-07-12 00:26:46.824409962
# house/livingroom/CO 0.005058744
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007765305
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020737684
# house/livingroom/temp 22.5
#
#
# house/livingroom/time 2020-07-12 00:27:23.700170040
# house/livingroom/CO 0.005036765
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007740884
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020668028
# house/livingroom/temp 22.5
#
#
# house/livingroom/time 2020-07-12 00:28:00.569649935
# house/livingroom/CO 0.005060218
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007766942
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020742353
# house/livingroom/temp 22.5
#
#
# house/livingroom/time 2020-07-12 00:28:37.325619936
# house/livingroom/CO 0.005058744
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007765305
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020737684
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:29:14.203619957
# house/livingroom/CO 0.005020762
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007723084
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020617265
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:29:51.068449974
# house/livingroom/CO 0.005038232
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007742515
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020672677
# house/livingroom/temp 22.5
#
#
# house/livingroom/time 2020-07-12 00:30:27.925509930
# house/livingroom/CO 0.005060218
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007766942
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020742353
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:31:04.790680170
# house/livingroom/CO 0.005058744
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007765305
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020737684
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:31:41.581350088
# house/livingroom/CO 0.005017841
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007719834
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020607997
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:32:18.456880093
# house/livingroom/CO 0.005013474
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007714973
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020594137
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:32:55.251219988
# house/livingroom/CO 0.005044092
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007749028
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020691255
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:33:32.110669851
# house/livingroom/CO 0.005029493
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007732798
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020644966
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:34:08.957280159
# house/livingroom/CO 0.005051393
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007757141
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020714395
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:34:45.803259850
# house/livingroom/CO 0.005012016
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00771335
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020589508
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:35:22.631209850
# house/livingroom/CO 0.005014975
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007716644
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.0205989
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:35:59.486590147
# house/livingroom/CO 0.005052864
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007758775
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020719057
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:36:36.328180075
# house/livingroom/CO 0.005054336
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00776041
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020723721
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:37:13.680340052
# house/livingroom/CO 0.005051393
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007757141
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020714395
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:37:50.548059940
# house/livingroom/CO 0.005052965
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007758888
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020719378
# house/livingroom/temp 22.6
# house/livingroom/time 2020-07-12 00:38:27.664119959
# house/livingroom/CO 0.005030915
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007734379
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020649475
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:39:04.524889946
# house/livingroom/CO 0.005023689
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007726342
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020626555
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:39:41.384490013
# house/livingroom/CO 0.005030957
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007734426
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020649609
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:40:18.488440037
# house/livingroom/CO 0.005051393
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007757141
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020714395
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:40:55.345309973
# house/livingroom/CO 0.005020767
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00772309
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020617282
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:41:32.151449919
# house/livingroom/CO 0.005010616
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007711791
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020585064
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:42:08.999919891
# house/livingroom/CO 0.005046993
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007752252
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.02070045
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:42:45.865520
# house/livingroom/CO 0.005009117
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007710122
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020580305
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:43:22.733940125
# house/livingroom/CO 0.005009159
# house/livingroom/humidity 51.3
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007710169
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020580438
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:43:59.560800076
# house/livingroom/CO 0.00502227
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007724763
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020622051
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:44:36.324140072
# house/livingroom/CO 0.004990396
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007689266
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020520845
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:45:13.188469887
# house/livingroom/CO 0.005009196
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00771021
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020580555
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:45:49.986930132
# house/livingroom/CO 0.005022186
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007724669
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020621784
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:46:26.843680143
# house/livingroom/CO 0.005000431
# house/livingroom/humidity 51.3
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007700449
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020552724
# house/livingroom/temp 22.7
#
#
# house/livingroom/time 2020-07-12 00:47:03.697550058
# house/livingroom/CO 0.005025115
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007727928
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020631076
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:47:40.559910059
# house/livingroom/CO 0.005016397
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007718227
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020603414
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:48:17.410730124
# house/livingroom/CO 0.004991763
# house/livingroom/humidity 50.6
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00769079
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020525187
# house/livingroom/temp 22.6
#
#
# house/livingroom/time 2020-07-12 00:48:54.190730095
# house/livingroom/CO 0.00501782
# house/livingroom/humidity 49.9
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00771981
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.02060793
# house/livingroom/temp 22.5
#
#
# house/livingroom/time 2020-07-12 00:49:31.002919912
# house/livingroom/CO 0.004990522
# house/livingroom/humidity 49.6
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007689407
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020521246
# house/livingroom/temp 22.5
#
#
# house/livingroom/time 2020-07-12 00:50:07.849900007
# house/livingroom/CO 0.005029493
# house/livingroom/humidity 49.4
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007732798
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020644966
# house/livingroom/temp 22.4
#
#
# house/livingroom/time 2020-07-12 00:50:44.708420038
# house/livingroom/CO 0.005009117
# house/livingroom/humidity 49.3
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007710122
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020580305
# house/livingroom/temp 22.3
#
#
# house/livingroom/time 2020-07-12 00:51:21.853189945
# house/livingroom/CO 0.005036807
# house/livingroom/humidity 49.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007740932
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020668162
# house/livingroom/temp 22.3
#
#
# house/livingroom/time 2020-07-12 00:51:58.595160007
# house/livingroom/CO 0.005001927
# house/livingroom/humidity 49.0
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007702115
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020557476
# house/livingroom/temp 22.2
#
#
# house/livingroom/time 2020-07-12 00:52:35.392899990
# house/livingroom/CO 0.004994671
# house/livingroom/humidity 48.9
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007694031
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020534428
# house/livingroom/temp 22.2
#
#
# house/livingroom/time 2020-07-12 00:53:12.531300067
# house/livingroom/CO 0.005030915
# house/livingroom/humidity 48.8
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007734379
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020649475
# house/livingroom/temp 22.1
#
#
# house/livingroom/time 2020-07-12 00:53:49.376690149
# house/livingroom/CO 0.005022228
# house/livingroom/humidity 48.9
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007724716
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020621918
# house/livingroom/temp 22.1
#
#
# house/livingroom/time 2020-07-12 00:54:26.475030184
# house/livingroom/CO 0.00501782
# house/livingroom/humidity 49.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00771981
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.02060793
# house/livingroom/temp 22.0
#
#
# house/livingroom/time 2020-07-12 00:55:03.333680153
# house/livingroom/CO 0.005009117
# house/livingroom/humidity 49.8
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007710122
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020580305
# house/livingroom/temp 22.0
#
#
# house/livingroom/time 2020-07-12 00:55:40.200439930
# house/livingroom/CO 0.004991763
# house/livingroom/humidity 50.3
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00769079
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020525187
# house/livingroom/temp 22.1
#
#
# house/livingroom/time 2020-07-12 00:56:17.061399937
# house/livingroom/CO 0.004991763
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00769079
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020525187
# house/livingroom/temp 22.1
# house/livingroom/time 2020-07-12 00:56:53.928769827
# house/livingroom/CO 0.005007697
# house/livingroom/humidity 50.8
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007708541
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020575797
# house/livingroom/temp 22.2
#
#
# house/livingroom/time 2020-07-12 00:57:30.796839952
# house/livingroom/CO 0.004980273
# house/livingroom/humidity 50.7
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00767798
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020488672
# house/livingroom/temp 22.2
#
#
# house/livingroom/time 2020-07-12 00:58:07.675729990
# house/livingroom/CO 0.005000431
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007700449
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020552724
# house/livingroom/temp 22.2
#
#
# house/livingroom/time 2020-07-12 00:58:44.559210062
# house/livingroom/CO 0.005003345
# house/livingroom/humidity 51.4
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007703695
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020561979
# house/livingroom/temp 22.3
#
#
# house/livingroom/time 2020-07-12 00:59:21.384310007
# house/livingroom/CO 0.005009117
# house/livingroom/humidity 51.3
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007710122
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020580305
# house/livingroom/temp 22.3
#
#
# house/livingroom/time 2020-07-12 00:59:58.178659916
# house/livingroom/CO 0.004980273
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00767798
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020488672
# house/livingroom/temp 22.3
#
#
# house/livingroom/time 2020-07-12 01:00:35.226300001
# house/livingroom/CO 0.005016397
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007718227
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020603414
# house/livingroom/temp 22.4
#
#
# house/livingroom/time 2020-07-12 01:01:12.345050097
# house/livingroom/CO 0.005003345
# house/livingroom/humidity 51.2
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007703695
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020561979
# house/livingroom/temp 22.4
#
#
# house/livingroom/time 2020-07-12 01:01:49.701269865
# house/livingroom/CO 0.005023652
# house/livingroom/humidity 51.1
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.007726301
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020626438
# house/livingroom/temp 22.4
#
#
# house/livingroom/time 2020-07-12 01:02:26.527419806
# house/livingroom/CO 0.004980273
# house/livingroom/humidity 51.3
# house/livingroom/lightdetected Off
# house/livingroom/lpg 0.00767798
# house/livingroom/motiondetected No
# house/livingroom/smoke 0.020488672
# house/livingroom/temp 22.4
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\users\crazy\appdata\local\programs\python\python38\lib\tkinter\__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "<ipython-input-9-d08b8b7b4de2>", line 55, in update_label
#     window.update()
#   File "c:\users\crazy\appdata\local\programs\python\python38\lib\tkinter\__init__.py", line 1305, in update
#     self.tk.call('update')
# _tkinter.TclError: can't invoke "update" command: application has been destroyed
